# %%
import networkx as nx
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import time

# %matplotlib inline

# %%
phase1 = pd.read_json('data/competition-output/phase1_holdout_publications.csv', dtype=object )
phase2 = pd.read_json('data/competition-output/phase2_holdout_publications.csv', dtype=object)
publications = pd.read_csv('data/publications.csv', dtype=object)

# %%
phase1.head(10)
# Out:
#   pdf_file_name    pub_date publication_id text_file_name  \
# 0       102.pdf  1969-01-01            102        102.txt
# 1       103.pdf  1969-01-01            103        103.txt
# 2       104.pdf  1969-01-01            104        104.txt
# 3       106.pdf  1969-01-01            106        106.txt
# 4       107.pdf  1969-01-01            107        107.txt
# 5       108.pdf  1969-01-01            108        108.txt
# 6       112.pdf  1969-01-01            112        112.txt
# 7       113.pdf  1969-01-01            113        113.txt
# 8       114.pdf  1969-01-01            114        114.txt
# 9       117.pdf  1969-01-01            117        117.txt
#
#                                                title unique_identifier
# 0  How does P2P lending fit into the consumer cre...             bbk-1
# 1  Moral Suasion in Regional Government Debt Markets             bbk-2
# 2  International monetary policy spillovers throu...             bbk-3
# ...

# %%
phase2.head()
# Out:
#   pdf_file_name    pub_date publication_id text_file_name  \
# 0     15491.pdf  2013-09-01          15491      15491.txt
# 1     15492.pdf  2016-07-27          15492      15492.txt
# 2     15493.pdf  2016-07-31          15493      15493.txt
# 3     15494.pdf  2016-06-29          15494      15494.txt
# 4     15495.pdf  2016-07-24          15495      15495.txt
#
#                                                title  \
# 0  Nursing Students' Perceptions of Taking Part i...
# 1  Learning From Others? Emulation and Change in ...
# 2                 The More You Talk, the Worse It Is
# 3  Neuronal Models for Sleep-Wake Regulation and ...
# 4  Physical Education and Back Health: Negotiatin...
#
#             unique_identifier
# 0  10.1177/010740831303300309
# 1    10.1177/0095327X15626725
# 2    10.1177/2329496515616813
# 3    10.1177/0748730407301239
# 4   10.1177/1356336X010072006

# %%
publications.head(10)
# Out:
#   pdf_file_name    pub_date publication_id text_file_name  \
# 0       105.pdf  1969-01-01            105        105.txt
# 1       109.pdf  1969-01-01            109        109.txt
# 2       110.pdf  1969-01-01            110        110.txt
# 3       111.pdf  1969-01-01            111        111.txt
# 4       115.pdf  1969-01-01            115        115.txt
# 5       116.pdf  1969-01-01            116        116.txt
# 6       119.pdf  1969-01-01            119        119.txt
# 7       122.pdf  1969-01-01            122        122.txt
# 8       123.pdf  1969-01-01            123        123.txt
# 9       124.pdf  1969-01-01            124        124.txt
#
#                                                title unique_identifier
# 0  Cheap Talk? Financial Sanctions and Non-Financ...             bbk-4
# 1  Banks' Trading after the Lehman Crisis - The R...             bbk-8
# 2  A Comprehensive View on Risk Reporting: Eviden...             bbk-9
# ...

# %%
df = pd.concat([phase1, phase2, publications])

# %%
df.head(10)
# Out:
#   pdf_file_name    pub_date publication_id text_file_name  \
# 0       102.pdf  1969-01-01            102        102.txt
# 1       103.pdf  1969-01-01            103        103.txt
# 2       104.pdf  1969-01-01            104        104.txt
# 3       106.pdf  1969-01-01            106        106.txt
# 4       107.pdf  1969-01-01            107        107.txt
# 5       108.pdf  1969-01-01            108        108.txt
# 6       112.pdf  1969-01-01            112        112.txt
# 7       113.pdf  1969-01-01            113        113.txt
# 8       114.pdf  1969-01-01            114        114.txt
# 9       117.pdf  1969-01-01            117        117.txt
#
#                                                title unique_identifier
# 0  How does P2P lending fit into the consumer cre...             bbk-1
# 1  Moral Suasion in Regional Government Debt Markets             bbk-2
# 2  International monetary policy spillovers throu...             bbk-3
# ...

# %%
#df.to_csv('allPub_doi.csv')

# %%
df.publication_id.nunique()
# Out:
# 15001

# %%
df.publication_id.shape
# Out:
# (15001,)
